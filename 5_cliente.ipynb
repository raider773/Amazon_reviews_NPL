# %%
# "Client" gives review and model predicts, app returns value. In this case positive or negative comment
import requests

# %%
def request (url,string):
    
    r = requests.post(url,
                  json = {'review':[string]})    
    
    if r.text == "0":
        return "Negative comment"
    elif r.text == "1":
        return "Positive comment"

# %%
consulta = request ('http://localhost:5000/api',"i cant use it at all")
consulta
# Out:
# 'Negative comment'

# %%
consulta = request ('http://localhost:5000/api',"i  use it all the time")
consulta
# Out:
# 'Positive comment'

# %%
consulta = request ('http://localhost:5000/api',"it sucks so bad ")
consulta
# Out:
# 'Negative comment'
